# %% [markdown]
# <a href="https://colab.research.google.com/github/AnaghBDeshpande/AI_Lab/blob/main/1BM22CS037_Simmulated_Annealing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import math

n=8

def no_of_conflicts(board):
    conflicts = 0
    n = len(board)
    for i in range(n):
        for j in range(i + 1, n):
            if board[i] == board[j] or abs(board[i] - board[j]) == j - i:
                conflicts += 1
    return conflicts

def initialize(n):
    return [random.randint(0, n - 1) for _ in range(n)]

def simulated_annealing(n, max_iterations=10000, initial_temp=100, cooling_rate=0.99):
    board = initialize(n)
    current_conflicts = no_of_conflicts(board)
    temperature = initial_temp

    for iteration in range(max_iterations):
        if current_conflicts == 0:
            print(f"Iteration {iteration}: Solution found!")
            print("Board Position:", board)
            return board

        row = random.randint(0, n - 1)
        new_col = random.randint(0, n - 1)
        while new_col == board[row]:
            new_col = random.randint(0, n - 1)

        new_board = board[:]
        new_board[row] = new_col
        new_conflicts = no_of_conflicts(new_board)
        delta_conflicts = new_conflicts - current_conflicts
        if delta_conflicts < 0 or math.exp(-delta_conflicts / temperature) > random.random():
            board, current_conflicts = new_board, new_conflicts
        print(f"Iteration {iteration}: Temperature={temperature:.2f}, Current Conflicts={current_conflicts}, "
              f"Delta Conflicts={delta_conflicts}, New Position for Row {row} -> Column {new_col}")
        print("Board Position:", board)
        temperature *= cooling_rate

    print("No solution found within the maximum iterations.")
    return None

solution = simulated_annealing(n)
if solution:
    print("Final Solution:", solution)
else:
    print("No solution found within the maximum iterations.")
# Out:
# Iteration 0: Temperature=100.00, Current Conflicts=8, Delta Conflicts=-2, New Position for Row 2 -> Column 1
# Board Position: [3, 6, 1, 6, 5, 7, 6, 3]
# Iteration 1: Temperature=99.00, Current Conflicts=8, Delta Conflicts=1, New Position for Row 5 -> Column 1
# Board Position: [3, 6, 1, 6, 5, 7, 6, 3]
# Iteration 2: Temperature=98.01, Current Conflicts=10, Delta Conflicts=2, New Position for Row 2 -> Column 3
# Board Position: [3, 6, 3, 6, 5, 7, 6, 3]
# Iteration 3: Temperature=97.03, Current Conflicts=9, Delta Conflicts=-1, New Position for Row 1 -> Column 1
# Board Position: [3, 1, 3, 6, 5, 7, 6, 3]
# Iteration 4: Temperature=96.06, Current Conflicts=8, Delta Conflicts=-1, New Position for Row 3 -> Column 7
# Board Position: [3, 1, 3, 7, 5, 7, 6, 3]
# Iteration 5: Temperature=95.10, Current Conflicts=7, Delta Conflicts=-1, New Position for Row 6 -> Column 5
# Board Position: [3, 1, 3, 7, 5, 7, 5, 3]
# Iteration 6: Temperature=94.15, Current Conflicts=10, Delta Conflicts=3, New Position for Row 1 -> Column 5
# Board Position: [3, 5, 3, 7, 5, 7, 5, 3]
# Iteration 7: Temperature=93.21, Current Conflicts=11, Delta Conflicts=1, New Position for Row 3 -> Column 3
# Board Position: [3, 5, 3, 3, 5, 7, 5, 3]
# Iteration 8: Temperature=92.27, Current Conflicts=9, Delta Conflicts=-2, New Position for Row 7 -> Column 6
# Board Position: [3, 5, 3, 3, 5, 7, 5, 6]
# Iteration 9: Temperature=91.35, Current Conflicts=13, Delta Conflicts=4, New Position for Row 5 -> Column 6
# Board Position: [3, 5, 3, 3, 5, 6, 5, 6]
# Iteration 10: Temperature=90.44, Current Conflicts=9, Delta Conflicts=-4, New Position for Row 5 -> Column 2
# Board Position: [3, 5, 3, 3, 5, 2, 5, 6]
# Iteration 11: Temperature=89.53, Current Conflicts=13, Delta Conflicts=4, New Position for Row 5 -> Column 6
# Board Position: [3, 5, 3, 3, 5, 6, 5, 6]
# Iteration 12: Temperature=88.64, Current Conflicts=12, Delta Conflicts=-1, New Position for Row 7 -> Column 2
# Board Position: [3, 5, 3, 3, 5, 6, 5, 2]
# Iteration 13: Temperature=87.75, Current Conflicts=12, Delta Conflicts=0, New Position for Row 1 -> Column 3
# Board Position: [3, 3, 3, 3, 5, 6, 5, 2]
# Iteration 14: Temperature=86.87, Current Conflicts=10, Delta Conflicts=-2, New Position for Row 3 -> Column 1
# Board Position: [3, 3, 3, 1, 5, 6, 5, 2]
# Iteration 15: Temperature=86.01, Current Conflicts=12, Delta Conflicts=2, New Position for Row 7 -> Column 3
# Board Position: [3, 3, 3, 1, 5, 6, 5, 3]
# Iteration 16: Temperature=85.15, Current Conflicts=9, Delta Conflicts=-3, New Position for Row 4 -> Column 4
# Board Position: [3, 3, 3, 1, 4, 6, 5, 3]
# Iteration 17: Temperature=84.29, Current Conflicts=14, Delta Conflicts=5, New Position for Row 4 -> Column 3
# Board Position: [3, 3, 3, 1, 3, 6, 5, 3]
# Iteration 18: Temperature=83.45, Current Conflicts=14, Delta Conflicts=0, New Position for Row 5 -> Column 5
# Board Position: [3, 3, 3, 1, 3, 5, 5, 3]
# Iteration 19: Temperature=82.62, Current Conflicts=11, Delta Conflicts=-3, New Position for Row 1 -> Column 4
# Board Position: [3, 4, 3, 1, 3, 5, 5, 3]
# Iteration 20: Temperature=81.79, Current Conflicts=12, Delta Conflicts=1, New Position for Row 2 -> Column 5
# Board Position: [3, 4, 5, 1, 3, 5, 5, 3]
# Iteration 21: Temperature=80.97, Current Conflicts=8, Delta Conflicts=-4, New Position for Row 2 -> Column 0
# Board Position: [3, 4, 0, 1, 3, 5, 5, 3]
# Iteration 22: Temperature=80.16, Current Conflicts=6, Delta Conflicts=-2, New Position for Row 7 -> Column 1
# Board Position: [3, 4, 0, 1, 3, 5, 5, 1]
# Iteration 23: Temperature=79.36, Current Conflicts=5, Delta Conflicts=-1, New Position for Row 6 -> Column 6
# Board Position: [3, 4, 0, 1, 3, 5, 6, 1]
# Iteration 24: Temperature=78.57, Current Conflicts=7, Delta Conflicts=2, New Position for Row 1 -> Column 3
# Board Position: [3, 3, 0, 1, 3, 5, 6, 1]
# Iteration 25: Temperature=77.78, Current Conflicts=7, Delta Conflicts=0, New Position for Row 0 -> Column 4
# Board Position: [4, 3, 0, 1, 3, 5, 6, 1]
# Iteration 26: Temperature=77.00, Current Conflicts=5, Delta Conflicts=-2, New Position for Row 3 -> Column 7
# Board Position: [4, 3, 0, 7, 3, 5, 6, 1]
# Iteration 27: Temperature=76.23, Current Conflicts=5, Delta Conflicts=2, New Position for Row 2 -> Column 1
# Board Position: [4, 3, 0, 7, 3, 5, 6, 1]
# Iteration 28: Temperature=75.47, Current Conflicts=6, Delta Conflicts=1, New Position for Row 6 -> Column 5
# Board Position: [4, 3, 0, 7, 3, 5, 5, 1]
# Iteration 29: Temperature=74.72, Current Conflicts=5, Delta Conflicts=-1, New Position for Row 4 -> Column 2
# Board Position: [4, 3, 0, 7, 2, 5, 5, 1]
# Iteration 30: Temperature=73.97, Current Conflicts=7, Delta Conflicts=2, New Position for Row 1 -> Column 1
# Board Position: [4, 1, 0, 7, 2, 5, 5, 1]
# Iteration 31: Temperature=73.23, Current Conflicts=8, Delta Conflicts=1, New Position for Row 0 -> Column 1
# Board Position: [1, 1, 0, 7, 2, 5, 5, 1]
# Iteration 32: Temperature=72.50, Current Conflicts=8, Delta Conflicts=0, New Position for Row 7 -> Column 3
# Board Position: [1, 1, 0, 7, 2, 5, 5, 3]
# Iteration 33: Temperature=71.77, Current Conflicts=8, Delta Conflicts=0, New Position for Row 1 -> Column 0
# Board Position: [1, 0, 0, 7, 2, 5, 5, 3]
# Iteration 34: Temperature=71.06, Current Conflicts=9, Delta Conflicts=1, New Position for Row 0 -> Column 5
# Board Position: [5, 0, 0, 7, 2, 5, 5, 3]
# Iteration 35: Temperature=70.34, Current Conflicts=8, Delta Conflicts=-1, New Position for Row 5 -> Column 0
# Board Position: [5, 0, 0, 7, 2, 0, 5, 3]
# Iteration 36: Temperature=69.64, Current Conflicts=8, Delta Conflicts=0, New Position for Row 2 -> Column 3
# Board Position: [5, 0, 3, 7, 2, 0, 5, 3]
# Iteration 37: Temperature=68.94, Current Conflicts=7, Delta Conflicts=-1, New Position for Row 2 -> Column 1
# Board Position: [5, 0, 1, 7, 2, 0, 5, 3]
# Iteration 38: Temperature=68.26, Current Conflicts=6, Delta Conflicts=-1, New Position for Row 0 -> Column 6
# Board Position: [6, 0, 1, 7, 2, 0, 5, 3]
# Iteration 39: Temperature=67.57, Current Conflicts=7, Delta Conflicts=1, New Position for Row 6 -> Column 4
# Board Position: [6, 0, 1, 7, 2, 0, 4, 3]
# Iteration 40: Temperature=66.90, Current Conflicts=7, Delta Conflicts=0, New Position for Row 7 -> Column 0
# Board Position: [6, 0, 1, 7, 2, 0, 4, 0]
# Iteration 41: Temperature=66.23, Current Conflicts=6, Delta Conflicts=-1, New Position for Row 4 -> Column 7
# Board Position: [6, 0, 1, 7, 7, 0, 4, 0]
# Iteration 42: Temperature=65.57, Current Conflicts=7, Delta Conflicts=1, New Position for Row 7 -> Column 6
# Board Position: [6, 0, 1, 7, 7, 0, 4, 6]
# Iteration 43: Temperature=64.91, Current Conflicts=7, Delta Conflicts=0, New Position for Row 2 -> Column 4
# Board Position: [6, 0, 4, 7, 7, 0, 4, 6]
# Iteration 44: Temperature=64.26, Current Conflicts=5, Delta Conflicts=-2, New Position for Row 6 -> Column 3
# Board Position: [6, 0, 4, 7, 7, 0, 3, 6]
# Iteration 45: Temperature=63.62, Current Conflicts=7, Delta Conflicts=2, New Position for Row 6 -> Column 6
# Board Position: [6, 0, 4, 7, 7, 0, 6, 6]
# Iteration 46: Temperature=62.98, Current Conflicts=6, Delta Conflicts=-1, New Position for Row 6 -> Column 1
# Board Position: [6, 0, 4, 7, 7, 0, 1, 6]
# Iteration 47: Temperature=62.35, Current Conflicts=5, Delta Conflicts=-1, New Position for Row 5 -> Column 5
# Board Position: [6, 0, 4, 7, 7, 5, 1, 6]
# Iteration 48: Temperature=61.73, Current Conflicts=5, Delta Conflicts=0, New Position for Row 7 -> Column 3
# Board Position: [6, 0, 4, 7, 7, 5, 1, 3]
# Iteration 49: Temperature=61.11, Current Conflicts=5, Delta Conflicts=4, New Position for Row 1 -> Column 5
# Board Position: [6, 0, 4, 7, 7, 5, 1, 3]
# Iteration 50: Temperature=60.50, Current Conflicts=7, Delta Conflicts=2, New Position for Row 1 -> Column 3
# Board Position: [6, 3, 4, 7, 7, 5, 1, 3]
# Iteration 51: Temperature=59.90, Current Conflicts=8, Delta Conflicts=1, New Position for Row 4 -> Column 0
# Board Position: [6, 3, 4, 7, 0, 5, 1, 3]
# Iteration 52: Temperature=59.30, Current Conflicts=7, Delta Conflicts=-1, New Position for Row 5 -> Column 6
# Board Position: [6, 3, 4, 7, 0, 6, 1, 3]
# Iteration 53: Temperature=58.70, Current Conflicts=7, Delta Conflicts=0, New Position for Row 4 -> Column 7
# Board Position: [6, 3, 4, 7, 7, 6, 1, 3]
# Iteration 54: Temperature=58.12, Current Conflicts=6, Delta Conflicts=-1, New Position for Row 5 -> Column 0
# Board Position: [6, 3, 4, 7, 7, 0, 1, 3]
# Iteration 55: Temperature=57.54, Current Conflicts=8, Delta Conflicts=2, New Position for Row 0 -> Column 4
# Board Position: [4, 3, 4, 7, 7, 0, 1, 3]
# Iteration 56: Temperature=56.96, Current Conflicts=8, Delta Conflicts=0, New Position for Row 3 -> Column 3
# Board Position: [4, 3, 4, 3, 7, 0, 1, 3]
# Iteration 57: Temperature=56.39, Current Conflicts=6, Delta Conflicts=-2, New Position for Row 2 -> Column 7
# Board Position: [4, 3, 7, 3, 7, 0, 1, 3]
# Iteration 58: Temperature=55.83, Current Conflicts=4, Delta Conflicts=-2, New Position for Row 1 -> Column 0
# Board Position: [4, 0, 7, 3, 7, 0, 1, 3]
# Iteration 59: Temperature=55.27, Current Conflicts=4, Delta Conflicts=2, New Position for Row 0 -> Column 5
# Board Position: [4, 0, 7, 3, 7, 0, 1, 3]
# Iteration 60: Temperature=54.72, Current Conflicts=7, Delta Conflicts=3, New Position for Row 0 -> Column 3
# Board Position: [3, 0, 7, 3, 7, 0, 1, 3]
# Iteration 61: Temperature=54.17, Current Conflicts=8, Delta Conflicts=1, New Position for Row 3 -> Column 6
# Board Position: [3, 0, 7, 6, 7, 0, 1, 3]
# Iteration 62: Temperature=53.63, Current Conflicts=6, Delta Conflicts=-2, New Position for Row 2 -> Column 4
# Board Position: [3, 0, 4, 6, 7, 0, 1, 3]
# Iteration 63: Temperature=53.09, Current Conflicts=7, Delta Conflicts=1, New Position for Row 6 -> Column 5
# Board Position: [3, 0, 4, 6, 7, 0, 5, 3]
# Iteration 64: Temperature=52.56, Current Conflicts=6, Delta Conflicts=-1, New Position for Row 0 -> Column 6
# Board Position: [6, 0, 4, 6, 7, 0, 5, 3]
# Iteration 65: Temperature=52.03, Current Conflicts=5, Delta Conflicts=-1, New Position for Row 3 -> Column 4
# Board Position: [6, 0, 4, 4, 7, 0, 5, 3]
# Iteration 66: Temperature=51.51, Current Conflicts=5, Delta Conflicts=0, New Position for Row 6 -> Column 7
# Board Position: [6, 0, 4, 4, 7, 0, 7, 3]
# Iteration 67: Temperature=51.00, Current Conflicts=8, Delta Conflicts=3, New Position for Row 7 -> Column 4
# Board Position: [6, 0, 4, 4, 7, 0, 7, 4]
# Iteration 68: Temperature=50.49, Current Conflicts=10, Delta Conflicts=2, New Position for Row 0 -> Column 7
# Board Position: [7, 0, 4, 4, 7, 0, 7, 4]
# Iteration 69: Temperature=49.98, Current Conflicts=7, Delta Conflicts=-3, New Position for Row 7 -> Column 1
# Board Position: [7, 0, 4, 4, 7, 0, 7, 1]
# Iteration 70: Temperature=49.48, Current Conflicts=9, Delta Conflicts=2, New Position for Row 2 -> Column 5
# Board Position: [7, 0, 5, 4, 7, 0, 7, 1]
# Iteration 71: Temperature=48.99, Current Conflicts=14, Delta Conflicts=5, New Position for Row 7 -> Column 0
# Board Position: [7, 0, 5, 4, 7, 0, 7, 0]
# Iteration 72: Temperature=48.50, Current Conflicts=10, Delta Conflicts=-4, New Position for Row 7 -> Column 5
# Board Position: [7, 0, 5, 4, 7, 0, 7, 5]
# Iteration 73: Temperature=48.01, Current Conflicts=9, Delta Conflicts=-1, New Position for Row 0 -> Column 1
# Board Position: [1, 0, 5, 4, 7, 0, 7, 5]
# Iteration 74: Temperature=47.53, Current Conflicts=8, Delta Conflicts=-1, New Position for Row 2 -> Column 1
# Board Position: [1, 0, 1, 4, 7, 0, 7, 5]
# Iteration 75: Temperature=47.06, Current Conflicts=5, Delta Conflicts=-3, New Position for Row 6 -> Column 2
# Board Position: [1, 0, 1, 4, 7, 0, 2, 5]
# Iteration 76: Temperature=46.59, Current Conflicts=4, Delta Conflicts=-1, New Position for Row 0 -> Column 7
# Board Position: [7, 0, 1, 4, 7, 0, 2, 5]
# Iteration 77: Temperature=46.12, Current Conflicts=5, Delta Conflicts=1, New Position for Row 1 -> Column 2
# Board Position: [7, 2, 1, 4, 7, 0, 2, 5]
# Iteration 78: Temperature=45.66, Current Conflicts=3, Delta Conflicts=-2, New Position for Row 1 -> Column 5
# Board Position: [7, 5, 1, 4, 7, 0, 2, 5]
# Iteration 79: Temperature=45.20, Current Conflicts=3, Delta Conflicts=0, New Position for Row 7 -> Column 3
# Board Position: [7, 5, 1, 4, 7, 0, 2, 3]
# Iteration 80: Temperature=44.75, Current Conflicts=6, Delta Conflicts=3, New Position for Row 5 -> Column 2
# Board Position: [7, 5, 1, 4, 7, 2, 2, 3]
# Iteration 81: Temperature=44.30, Current Conflicts=7, Delta Conflicts=1, New Position for Row 7 -> Column 1
# Board Position: [7, 5, 1, 4, 7, 2, 2, 1]
# Iteration 82: Temperature=43.86, Current Conflicts=9, Delta Conflicts=2, New Position for Row 2 -> Column 6
# Board Position: [7, 5, 6, 4, 7, 2, 2, 1]
# Iteration 83: Temperature=43.42, Current Conflicts=9, Delta Conflicts=3, New Position for Row 4 -> Column 4
# Board Position: [7, 5, 6, 4, 7, 2, 2, 1]
# Iteration 84: Temperature=42.99, Current Conflicts=7, Delta Conflicts=-2, New Position for Row 6 -> Column 4
# Board Position: [7, 5, 6, 4, 7, 2, 4, 1]
# Iteration 85: Temperature=42.56, Current Conflicts=7, Delta Conflicts=0, New Position for Row 5 -> Column 1
# Board Position: [7, 5, 6, 4, 7, 1, 4, 1]
# Iteration 86: Temperature=42.13, Current Conflicts=8, Delta Conflicts=1, New Position for Row 7 -> Column 4
# Board Position: [7, 5, 6, 4, 7, 1, 4, 4]
# Iteration 87: Temperature=41.71, Current Conflicts=8, Delta Conflicts=0, New Position for Row 4 -> Column 6
# Board Position: [7, 5, 6, 4, 6, 1, 4, 4]
# Iteration 88: Temperature=41.29, Current Conflicts=7, Delta Conflicts=-1, New Position for Row 5 -> Column 0
# Board Position: [7, 5, 6, 4, 6, 0, 4, 4]
# Iteration 89: Temperature=40.88, Current Conflicts=5, Delta Conflicts=-2, New Position for Row 6 -> Column 2
# Board Position: [7, 5, 6, 4, 6, 0, 2, 4]
# Iteration 90: Temperature=40.47, Current Conflicts=7, Delta Conflicts=2, New Position for Row 7 -> Column 0
# Board Position: [7, 5, 6, 4, 6, 0, 2, 0]
# Iteration 91: Temperature=40.07, Current Conflicts=7, Delta Conflicts=0, New Position for Row 1 -> Column 3
# Board Position: [7, 3, 6, 4, 6, 0, 2, 0]
# Iteration 92: Temperature=39.67, Current Conflicts=9, Delta Conflicts=2, New Position for Row 5 -> Column 3
# Board Position: [7, 3, 6, 4, 6, 3, 2, 0]
# Iteration 93: Temperature=39.27, Current Conflicts=12, Delta Conflicts=3, New Position for Row 4 -> Column 3
# Board Position: [7, 3, 6, 4, 3, 3, 2, 0]
# Iteration 94: Temperature=38.88, Current Conflicts=8, Delta Conflicts=-4, New Position for Row 4 -> Column 5
# Board Position: [7, 3, 6, 4, 5, 3, 2, 0]
# Iteration 95: Temperature=38.49, Current Conflicts=12, Delta Conflicts=4, New Position for Row 4 -> Column 3
# Board Position: [7, 3, 6, 4, 3, 3, 2, 0]
# Iteration 96: Temperature=38.10, Current Conflicts=9, Delta Conflicts=-3, New Position for Row 4 -> Column 6
# Board Position: [7, 3, 6, 4, 6, 3, 2, 0]
# Iteration 97: Temperature=37.72, Current Conflicts=7, Delta Conflicts=-2, New Position for Row 2 -> Column 7
# Board Position: [7, 3, 7, 4, 6, 3, 2, 0]
# Iteration 98: Temperature=37.35, Current Conflicts=6, Delta Conflicts=-1, New Position for Row 2 -> Column 1
# Board Position: [7, 3, 1, 4, 6, 3, 2, 0]
# Iteration 99: Temperature=36.97, Current Conflicts=9, Delta Conflicts=3, New Position for Row 2 -> Column 3
# Board Position: [7, 3, 3, 4, 6, 3, 2, 0]
# Iteration 100: Temperature=36.60, Current Conflicts=9, Delta Conflicts=0, New Position for Row 6 -> Column 0
# Board Position: [7, 3, 3, 4, 6, 3, 0, 0]
# Iteration 101: Temperature=36.24, Current Conflicts=6, Delta Conflicts=-3, New Position for Row 2 -> Column 1
# Board Position: [7, 3, 1, 4, 6, 3, 0, 0]
# Iteration 102: Temperature=35.87, Current Conflicts=9, Delta Conflicts=3, New Position for Row 6 -> Column 1
# Board Position: [7, 3, 1, 4, 6, 3, 1, 0]
# Iteration 103: Temperature=35.52, Current Conflicts=10, Delta Conflicts=1, New Position for Row 5 -> Column 6
# Board Position: [7, 3, 1, 4, 6, 6, 1, 0]
# Iteration 104: Temperature=35.16, Current Conflicts=8, Delta Conflicts=-2, New Position for Row 7 -> Column 7
# Board Position: [7, 3, 1, 4, 6, 6, 1, 7]
# Iteration 105: Temperature=34.81, Current Conflicts=7, Delta Conflicts=-1, New Position for Row 0 -> Column 4
# Board Position: [4, 3, 1, 4, 6, 6, 1, 7]
# Iteration 106: Temperature=34.46, Current Conflicts=9, Delta Conflicts=2, New Position for Row 2 -> Column 6
# Board Position: [4, 3, 6, 4, 6, 6, 1, 7]
# Iteration 107: Temperature=34.12, Current Conflicts=8, Delta Conflicts=-1, New Position for Row 3 -> Column 3
# Board Position: [4, 3, 6, 3, 6, 6, 1, 7]
# Iteration 108: Temperature=33.78, Current Conflicts=9, Delta Conflicts=1, New Position for Row 2 -> Column 2
# Board Position: [4, 3, 2, 3, 6, 6, 1, 7]
# Iteration 109: Temperature=33.44, Current Conflicts=9, Delta Conflicts=0, New Position for Row 1 -> Column 1
# Board Position: [4, 1, 2, 3, 6, 6, 1, 7]
# Iteration 110: Temperature=33.10, Current Conflicts=11, Delta Conflicts=2, New Position for Row 0 -> Column 6
# Board Position: [6, 1, 2, 3, 6, 6, 1, 7]
# Iteration 111: Temperature=32.77, Current Conflicts=8, Delta Conflicts=-3, New Position for Row 0 -> Column 5
# Board Position: [5, 1, 2, 3, 6, 6, 1, 7]
# Iteration 112: Temperature=32.44, Current Conflicts=8, Delta Conflicts=0, New Position for Row 3 -> Column 1
# Board Position: [5, 1, 2, 1, 6, 6, 1, 7]
# Iteration 113: Temperature=32.12, Current Conflicts=8, Delta Conflicts=2, New Position for Row 0 -> Column 7
# Board Position: [5, 1, 2, 1, 6, 6, 1, 7]
# Iteration 114: Temperature=31.80, Current Conflicts=6, Delta Conflicts=-2, New Position for Row 2 -> Column 4
# Board Position: [5, 1, 4, 1, 6, 6, 1, 7]
# Iteration 115: Temperature=31.48, Current Conflicts=4, Delta Conflicts=-2, New Position for Row 1 -> Column 2
# Board Position: [5, 2, 4, 1, 6, 6, 1, 7]
# Iteration 116: Temperature=31.17, Current Conflicts=5, Delta Conflicts=1, New Position for Row 4 -> Column 5
# Board Position: [5, 2, 4, 1, 5, 6, 1, 7]
# Iteration 117: Temperature=30.85, Current Conflicts=5, Delta Conflicts=4, New Position for Row 2 -> Column 3
# Board Position: [5, 2, 4, 1, 5, 6, 1, 7]
# Iteration 118: Temperature=30.55, Current Conflicts=8, Delta Conflicts=3, New Position for Row 2 -> Column 5
# Board Position: [5, 2, 5, 1, 5, 6, 1, 7]
# Iteration 119: Temperature=30.24, Current Conflicts=9, Delta Conflicts=1, New Position for Row 0 -> Column 7
# Board Position: [7, 2, 5, 1, 5, 6, 1, 7]
# Iteration 120: Temperature=29.94, Current Conflicts=9, Delta Conflicts=0, New Position for Row 2 -> Column 7
# Board Position: [7, 2, 7, 1, 5, 6, 1, 7]
# Iteration 121: Temperature=29.64, Current Conflicts=7, Delta Conflicts=-2, New Position for Row 4 -> Column 0
# Board Position: [7, 2, 7, 1, 0, 6, 1, 7]
# Iteration 122: Temperature=29.34, Current Conflicts=7, Delta Conflicts=0, New Position for Row 6 -> Column 2
# Board Position: [7, 2, 7, 1, 0, 6, 2, 7]
# Iteration 123: Temperature=29.05, Current Conflicts=8, Delta Conflicts=1, New Position for Row 1 -> Column 6
# Board Position: [7, 6, 7, 1, 0, 6, 2, 7]
# Iteration 124: Temperature=28.76, Current Conflicts=8, Delta Conflicts=0, New Position for Row 5 -> Column 5
# Board Position: [7, 6, 7, 1, 0, 5, 2, 7]
# Iteration 125: Temperature=28.47, Current Conflicts=8, Delta Conflicts=2, New Position for Row 5 -> Column 7
# Board Position: [7, 6, 7, 1, 0, 5, 2, 7]
# Iteration 126: Temperature=28.19, Current Conflicts=8, Delta Conflicts=0, New Position for Row 3 -> Column 2
# Board Position: [7, 6, 7, 2, 0, 5, 2, 7]
# Iteration 127: Temperature=27.90, Current Conflicts=8, Delta Conflicts=0, New Position for Row 4 -> Column 1
# Board Position: [7, 6, 7, 2, 1, 5, 2, 7]
# Iteration 128: Temperature=27.63, Current Conflicts=5, Delta Conflicts=-3, New Position for Row 2 -> Column 4
# Board Position: [7, 6, 4, 2, 1, 5, 2, 7]
# Iteration 129: Temperature=27.35, Current Conflicts=4, Delta Conflicts=-1, New Position for Row 3 -> Column 0
# Board Position: [7, 6, 4, 0, 1, 5, 2, 7]
# Iteration 130: Temperature=27.08, Current Conflicts=4, Delta Conflicts=0, New Position for Row 3 -> Column 6
# Board Position: [7, 6, 4, 6, 1, 5, 2, 7]
# Iteration 131: Temperature=26.80, Current Conflicts=4, Delta Conflicts=0, New Position for Row 5 -> Column 0
# Board Position: [7, 6, 4, 6, 1, 0, 2, 7]
# Iteration 132: Temperature=26.54, Current Conflicts=6, Delta Conflicts=2, New Position for Row 4 -> Column 7
# Board Position: [7, 6, 4, 6, 7, 0, 2, 7]
# Iteration 133: Temperature=26.27, Current Conflicts=8, Delta Conflicts=2, New Position for Row 5 -> Column 4
# Board Position: [7, 6, 4, 6, 7, 4, 2, 7]
# Iteration 134: Temperature=26.01, Current Conflicts=7, Delta Conflicts=-1, New Position for Row 1 -> Column 2
# Board Position: [7, 2, 4, 6, 7, 4, 2, 7]
# Iteration 135: Temperature=25.75, Current Conflicts=6, Delta Conflicts=-1, New Position for Row 0 -> Column 1
# Board Position: [1, 2, 4, 6, 7, 4, 2, 7]
# Iteration 136: Temperature=25.49, Current Conflicts=5, Delta Conflicts=-1, New Position for Row 4 -> Column 0
# Board Position: [1, 2, 4, 6, 0, 4, 2, 7]
# Iteration 137: Temperature=25.24, Current Conflicts=4, Delta Conflicts=-1, New Position for Row 5 -> Column 0
# Board Position: [1, 2, 4, 6, 0, 0, 2, 7]
# Iteration 138: Temperature=24.98, Current Conflicts=6, Delta Conflicts=2, New Position for Row 3 -> Column 5
# Board Position: [1, 2, 4, 5, 0, 0, 2, 7]
# Iteration 139: Temperature=24.73, Current Conflicts=4, Delta Conflicts=-2, New Position for Row 6 -> Column 4
# Board Position: [1, 2, 4, 5, 0, 0, 4, 7]
# Iteration 140: Temperature=24.49, Current Conflicts=4, Delta Conflicts=0, New Position for Row 6 -> Column 5
# Board Position: [1, 2, 4, 5, 0, 0, 5, 7]
# Iteration 141: Temperature=24.24, Current Conflicts=4, Delta Conflicts=0, New Position for Row 3 -> Column 1
# Board Position: [1, 2, 4, 1, 0, 0, 5, 7]
# Iteration 142: Temperature=24.00, Current Conflicts=4, Delta Conflicts=0, New Position for Row 4 -> Column 4
# Board Position: [1, 2, 4, 1, 4, 0, 5, 7]
# Iteration 143: Temperature=23.76, Current Conflicts=3, Delta Conflicts=-1, New Position for Row 0 -> Column 3
# Board Position: [3, 2, 4, 1, 4, 0, 5, 7]
# Iteration 144: Temperature=23.52, Current Conflicts=5, Delta Conflicts=2, New Position for Row 5 -> Column 6
# Board Position: [3, 2, 4, 1, 4, 6, 5, 7]
# Iteration 145: Temperature=23.29, Current Conflicts=5, Delta Conflicts=0, New Position for Row 6 -> Column 1
# Board Position: [3, 2, 4, 1, 4, 6, 1, 7]
# Iteration 146: Temperature=23.05, Current Conflicts=5, Delta Conflicts=0, New Position for Row 3 -> Column 2
# Board Position: [3, 2, 4, 2, 4, 6, 1, 7]
# Iteration 147: Temperature=22.82, Current Conflicts=6, Delta Conflicts=1, New Position for Row 3 -> Column 5
# Board Position: [3, 2, 4, 5, 4, 6, 1, 7]
# Iteration 148: Temperature=22.59, Current Conflicts=5, Delta Conflicts=-1, New Position for Row 3 -> Column 2
# Board Position: [3, 2, 4, 2, 4, 6, 1, 7]
# Iteration 149: Temperature=22.37, Current Conflicts=5, Delta Conflicts=0, New Position for Row 4 -> Column 6
# Board Position: [3, 2, 4, 2, 6, 6, 1, 7]
# Iteration 150: Temperature=22.15, Current Conflicts=5, Delta Conflicts=0, New Position for Row 2 -> Column 7
# Board Position: [3, 2, 7, 2, 6, 6, 1, 7]
# Iteration 151: Temperature=21.92, Current Conflicts=8, Delta Conflicts=3, New Position for Row 2 -> Column 1
# Board Position: [3, 2, 1, 2, 6, 6, 1, 7]
# Iteration 152: Temperature=21.70, Current Conflicts=7, Delta Conflicts=-1, New Position for Row 4 -> Column 0
# Board Position: [3, 2, 1, 2, 0, 6, 1, 7]
# Iteration 153: Temperature=21.49, Current Conflicts=7, Delta Conflicts=0, New Position for Row 2 -> Column 3
# Board Position: [3, 2, 3, 2, 0, 6, 1, 7]
# Iteration 154: Temperature=21.27, Current Conflicts=4, Delta Conflicts=-3, New Position for Row 2 -> Column 0
# Board Position: [3, 2, 0, 2, 0, 6, 1, 7]
# Iteration 155: Temperature=21.06, Current Conflicts=6, Delta Conflicts=2, New Position for Row 3 -> Column 4
# Board Position: [3, 2, 0, 4, 0, 6, 1, 7]
# Iteration 156: Temperature=20.85, Current Conflicts=6, Delta Conflicts=1, New Position for Row 4 -> Column 2
# Board Position: [3, 2, 0, 4, 0, 6, 1, 7]
# Iteration 157: Temperature=20.64, Current Conflicts=6, Delta Conflicts=0, New Position for Row 1 -> Column 6
# Board Position: [3, 6, 0, 4, 0, 6, 1, 7]
# Iteration 158: Temperature=20.43, Current Conflicts=9, Delta Conflicts=3, New Position for Row 0 -> Column 1
# Board Position: [1, 6, 0, 4, 0, 6, 1, 7]
# Iteration 159: Temperature=20.23, Current Conflicts=7, Delta Conflicts=-2, New Position for Row 1 -> Column 7
# Board Position: [1, 7, 0, 4, 0, 6, 1, 7]
# Iteration 160: Temperature=20.03, Current Conflicts=10, Delta Conflicts=3, New Position for Row 6 -> Column 7
# Board Position: [1, 7, 0, 4, 0, 6, 7, 7]
# Iteration 161: Temperature=19.83, Current Conflicts=10, Delta Conflicts=3, New Position for Row 4 -> Column 5
# Board Position: [1, 7, 0, 4, 0, 6, 7, 7]
# Iteration 162: Temperature=19.63, Current Conflicts=8, Delta Conflicts=-2, New Position for Row 5 -> Column 2
# Board Position: [1, 7, 0, 4, 0, 2, 7, 7]
# Iteration 163: Temperature=19.43, Current Conflicts=8, Delta Conflicts=0, New Position for Row 5 -> Column 5
# Board Position: [1, 7, 0, 4, 0, 5, 7, 7]
# Iteration 164: Temperature=19.24, Current Conflicts=10, Delta Conflicts=2, New Position for Row 0 -> Column 0
# Board Position: [0, 7, 0, 4, 0, 5, 7, 7]
# Iteration 165: Temperature=19.05, Current Conflicts=8, Delta Conflicts=-2, New Position for Row 0 -> Column 4
# Board Position: [4, 7, 0, 4, 0, 5, 7, 7]
# Iteration 166: Temperature=18.86, Current Conflicts=9, Delta Conflicts=1, New Position for Row 5 -> Column 3
# Board Position: [4, 7, 0, 4, 0, 3, 7, 7]
# Iteration 167: Temperature=18.67, Current Conflicts=9, Delta Conflicts=0, New Position for Row 4 -> Column 3
# Board Position: [4, 7, 0, 4, 3, 3, 7, 7]
# Iteration 168: Temperature=18.48, Current Conflicts=7, Delta Conflicts=-2, New Position for Row 4 -> Column 1
# Board Position: [4, 7, 0, 4, 1, 3, 7, 7]
# Iteration 169: Temperature=18.30, Current Conflicts=7, Delta Conflicts=0, New Position for Row 7 -> Column 0
# Board Position: [4, 7, 0, 4, 1, 3, 7, 0]
# Iteration 170: Temperature=18.11, Current Conflicts=8, Delta Conflicts=1, New Position for Row 7 -> Column 1
# Board Position: [4, 7, 0, 4, 1, 3, 7, 1]
# Iteration 171: Temperature=17.93, Current Conflicts=9, Delta Conflicts=1, New Position for Row 4 -> Column 5
# Board Position: [4, 7, 0, 4, 5, 3, 7, 1]
# Iteration 172: Temperature=17.75, Current Conflicts=8, Delta Conflicts=-1, New Position for Row 1 -> Column 1
# Board Position: [4, 1, 0, 4, 5, 3, 7, 1]
# Iteration 173: Temperature=17.57, Current Conflicts=7, Delta Conflicts=-1, New Position for Row 4 -> Column 7
# Board Position: [4, 1, 0, 4, 7, 3, 7, 1]
# Iteration 174: Temperature=17.40, Current Conflicts=6, Delta Conflicts=-1, New Position for Row 0 -> Column 5
# Board Position: [5, 1, 0, 4, 7, 3, 7, 1]
# Iteration 175: Temperature=17.22, Current Conflicts=6, Delta Conflicts=0, New Position for Row 1 -> Column 6
# Board Position: [5, 6, 0, 4, 7, 3, 7, 1]
# Iteration 176: Temperature=17.05, Current Conflicts=5, Delta Conflicts=-1, New Position for Row 1 -> Column 3
# Board Position: [5, 3, 0, 4, 7, 3, 7, 1]
# Iteration 177: Temperature=16.88, Current Conflicts=6, Delta Conflicts=1, New Position for Row 4 -> Column 0
# Board Position: [5, 3, 0, 4, 0, 3, 7, 1]
# Iteration 178: Temperature=16.71, Current Conflicts=8, Delta Conflicts=2, New Position for Row 0 -> Column 0
# Board Position: [0, 3, 0, 4, 0, 3, 7, 1]
# Iteration 179: Temperature=16.55, Current Conflicts=7, Delta Conflicts=-1, New Position for Row 3 -> Column 2
# Board Position: [0, 3, 0, 2, 0, 3, 7, 1]
# Iteration 180: Temperature=16.38, Current Conflicts=7, Delta Conflicts=0, New Position for Row 4 -> Column 2
# Board Position: [0, 3, 0, 2, 2, 3, 7, 1]
# Iteration 181: Temperature=16.22, Current Conflicts=4, Delta Conflicts=-3, New Position for Row 5 -> Column 4
# Board Position: [0, 3, 0, 2, 2, 4, 7, 1]
# Iteration 182: Temperature=16.05, Current Conflicts=3, Delta Conflicts=-1, New Position for Row 2 -> Column 6
# Board Position: [0, 3, 6, 2, 2, 4, 7, 1]
# Iteration 183: Temperature=15.89, Current Conflicts=4, Delta Conflicts=1, New Position for Row 0 -> Column 3
# Board Position: [3, 3, 6, 2, 2, 4, 7, 1]
# Iteration 184: Temperature=15.74, Current Conflicts=4, Delta Conflicts=0, New Position for Row 7 -> Column 4
# Board Position: [3, 3, 6, 2, 2, 4, 7, 4]
# Iteration 185: Temperature=15.58, Current Conflicts=6, Delta Conflicts=2, New Position for Row 4 -> Column 4
# Board Position: [3, 3, 6, 2, 4, 4, 7, 4]
# Iteration 186: Temperature=15.42, Current Conflicts=6, Delta Conflicts=0, New Position for Row 3 -> Column 1
# Board Position: [3, 3, 6, 1, 4, 4, 7, 4]
# Iteration 187: Temperature=15.27, Current Conflicts=9, Delta Conflicts=3, New Position for Row 3 -> Column 4
# Board Position: [3, 3, 6, 4, 4, 4, 7, 4]
# Iteration 188: Temperature=15.12, Current Conflicts=7, Delta Conflicts=-2, New Position for Row 3 -> Column 7
# Board Position: [3, 3, 6, 7, 4, 4, 7, 4]
# Iteration 189: Temperature=14.96, Current Conflicts=7, Delta Conflicts=0, New Position for Row 1 -> Column 0
# Board Position: [3, 0, 6, 7, 4, 4, 7, 4]
# Iteration 190: Temperature=14.81, Current Conflicts=8, Delta Conflicts=1, New Position for Row 6 -> Column 6
# Board Position: [3, 0, 6, 7, 4, 4, 6, 4]
# Iteration 191: Temperature=14.67, Current Conflicts=8, Delta Conflicts=0, New Position for Row 0 -> Column 2
# Board Position: [2, 0, 6, 7, 4, 4, 6, 4]
# Iteration 192: Temperature=14.52, Current Conflicts=7, Delta Conflicts=-1, New Position for Row 7 -> Column 5
# Board Position: [2, 0, 6, 7, 4, 4, 6, 5]
# Iteration 193: Temperature=14.37, Current Conflicts=6, Delta Conflicts=-1, New Position for Row 4 -> Column 3
# Board Position: [2, 0, 6, 7, 3, 4, 6, 5]
# Iteration 194: Temperature=14.23, Current Conflicts=5, Delta Conflicts=-1, New Position for Row 1 -> Column 4
# Board Position: [2, 4, 6, 7, 3, 4, 6, 5]
# Iteration 195: Temperature=14.09, Current Conflicts=6, Delta Conflicts=1, New Position for Row 7 -> Column 3
# Board Position: [2, 4, 6, 7, 3, 4, 6, 3]
# Iteration 196: Temperature=13.95, Current Conflicts=6, Delta Conflicts=2, New Position for Row 1 -> Column 3
# Board Position: [2, 4, 6, 7, 3, 4, 6, 3]
# Iteration 197: Temperature=13.81, Current Conflicts=7, Delta Conflicts=1, New Position for Row 2 -> Column 3
# Board Position: [2, 4, 3, 7, 3, 4, 6, 3]
# Iteration 198: Temperature=13.67, Current Conflicts=8, Delta Conflicts=1, New Position for Row 5 -> Column 7
# Board Position: [2, 4, 3, 7, 3, 7, 6, 3]
# Iteration 199: Temperature=13.53, Current Conflicts=8, Delta Conflicts=0, New Position for Row 2 -> Column 4
# Board Position: [2, 4, 4, 7, 3, 7, 6, 3]
# Iteration 200: Temperature=13.40, Current Conflicts=8, Delta Conflicts=0, New Position for Row 7 -> Column 5
# Board Position: [2, 4, 4, 7, 3, 7, 6, 5]
# Iteration 201: Temperature=13.26, Current Conflicts=11, Delta Conflicts=3, New Position for Row 4 -> Column 4
# Board Position: [2, 4, 4, 7, 4, 7, 6, 5]
# Iteration 202: Temperature=13.13, Current Conflicts=9, Delta Conflicts=-2, New Position for Row 4 -> Column 5
# Board Position: [2, 4, 4, 7, 5, 7, 6, 5]
# Iteration 203: Temperature=13.00, Current Conflicts=9, Delta Conflicts=0, New Position for Row 6 -> Column 5
# Board Position: [2, 4, 4, 7, 5, 7, 5, 5]
# Iteration 204: Temperature=12.87, Current Conflicts=6, Delta Conflicts=-3, New Position for Row 7 -> Column 1
# Board Position: [2, 4, 4, 7, 5, 7, 5, 1]
# Iteration 205: Temperature=12.74, Current Conflicts=11, Delta Conflicts=5, New Position for Row 3 -> Column 5
# Board Position: [2, 4, 4, 5, 5, 7, 5, 1]
# Iteration 206: Temperature=12.61, Current Conflicts=11, Delta Conflicts=0, New Position for Row 2 -> Column 5
# Board Position: [2, 4, 5, 5, 5, 7, 5, 1]
# Iteration 207: Temperature=12.49, Current Conflicts=11, Delta Conflicts=0, New Position for Row 5 -> Column 3
# Board Position: [2, 4, 5, 5, 5, 3, 5, 1]
# Iteration 208: Temperature=12.36, Current Conflicts=10, Delta Conflicts=-1, New Position for Row 7 -> Column 0
# Board Position: [2, 4, 5, 5, 5, 3, 5, 0]
# Iteration 209: Temperature=12.24, Current Conflicts=8, Delta Conflicts=-2, New Position for Row 2 -> Column 3
# Board Position: [2, 4, 3, 5, 5, 3, 5, 0]
# Iteration 210: Temperature=12.12, Current Conflicts=5, Delta Conflicts=-3, New Position for Row 3 -> Column 1
# Board Position: [2, 4, 3, 1, 5, 3, 5, 0]
# Iteration 211: Temperature=12.00, Current Conflicts=4, Delta Conflicts=-1, New Position for Row 2 -> Column 4
# Board Position: [2, 4, 4, 1, 5, 3, 5, 0]
# Iteration 212: Temperature=11.88, Current Conflicts=5, Delta Conflicts=1, New Position for Row 1 -> Column 1
# Board Position: [2, 1, 4, 1, 5, 3, 5, 0]
# Iteration 213: Temperature=11.76, Current Conflicts=5, Delta Conflicts=0, New Position for Row 4 -> Column 7
# Board Position: [2, 1, 4, 1, 7, 3, 5, 0]
# Iteration 214: Temperature=11.64, Current Conflicts=5, Delta Conflicts=2, New Position for Row 2 -> Column 1
# Board Position: [2, 1, 4, 1, 7, 3, 5, 0]
# Iteration 215: Temperature=11.52, Current Conflicts=4, Delta Conflicts=-1, New Position for Row 3 -> Column 6
# Board Position: [2, 1, 4, 6, 7, 3, 5, 0]
# Iteration 216: Temperature=11.41, Current Conflicts=4, Delta Conflicts=0, New Position for Row 0 -> Column 6
# Board Position: [6, 1, 4, 6, 7, 3, 5, 0]
# Iteration 217: Temperature=11.29, Current Conflicts=7, Delta Conflicts=3, New Position for Row 5 -> Column 4
# Board Position: [6, 1, 4, 6, 7, 4, 5, 0]
# Iteration 218: Temperature=11.18, Current Conflicts=11, Delta Conflicts=4, New Position for Row 1 -> Column 4
# Board Position: [6, 4, 4, 6, 7, 4, 5, 0]
# Iteration 219: Temperature=11.07, Current Conflicts=9, Delta Conflicts=-2, New Position for Row 4 -> Column 1
# Board Position: [6, 4, 4, 6, 1, 4, 5, 0]
# Iteration 220: Temperature=10.96, Current Conflicts=6, Delta Conflicts=-3, New Position for Row 3 -> Column 7
# Board Position: [6, 4, 4, 7, 1, 4, 5, 0]
# Iteration 221: Temperature=10.85, Current Conflicts=3, Delta Conflicts=-3, New Position for Row 1 -> Column 2
# Board Position: [6, 2, 4, 7, 1, 4, 5, 0]
# Iteration 222: Temperature=10.74, Current Conflicts=4, Delta Conflicts=1, New Position for Row 0 -> Column 5
# Board Position: [5, 2, 4, 7, 1, 4, 5, 0]
# Iteration 223: Temperature=10.63, Current Conflicts=6, Delta Conflicts=2, New Position for Row 2 -> Column 5
# Board Position: [5, 2, 5, 7, 1, 4, 5, 0]
# Iteration 224: Temperature=10.53, Current Conflicts=9, Delta Conflicts=3, New Position for Row 4 -> Column 3
# Board Position: [5, 2, 5, 7, 3, 4, 5, 0]
# Iteration 225: Temperature=10.42, Current Conflicts=9, Delta Conflicts=0, New Position for Row 7 -> Column 4
# Board Position: [5, 2, 5, 7, 3, 4, 5, 4]
# Iteration 226: Temperature=10.32, Current Conflicts=5, Delta Conflicts=-4, New Position for Row 6 -> Column 2
# Board Position: [5, 2, 5, 7, 3, 4, 2, 4]
# Iteration 227: Temperature=10.21, Current Conflicts=5, Delta Conflicts=2, New Position for Row 4 -> Column 5
# Board Position: [5, 2, 5, 7, 3, 4, 2, 4]
# Iteration 228: Temperature=10.11, Current Conflicts=5, Delta Conflicts=2, New Position for Row 6 -> Column 4
# Board Position: [5, 2, 5, 7, 3, 4, 2, 4]
# Iteration 229: Temperature=10.01, Current Conflicts=5, Delta Conflicts=0, New Position for Row 3 -> Column 1
# Board Position: [5, 2, 5, 1, 3, 4, 2, 4]
# Iteration 230: Temperature=9.91, Current Conflicts=6, Delta Conflicts=1, New Position for Row 1 -> Column 3
# Board Position: [5, 3, 5, 1, 3, 4, 2, 4]
# Iteration 231: Temperature=9.81, Current Conflicts=5, Delta Conflicts=-1, New Position for Row 2 -> Column 0
# Board Position: [5, 3, 0, 1, 3, 4, 2, 4]
# Iteration 232: Temperature=9.71, Current Conflicts=4, Delta Conflicts=-1, New Position for Row 3 -> Column 6
# Board Position: [5, 3, 0, 6, 3, 4, 2, 4]
# Iteration 233: Temperature=9.62, Current Conflicts=3, Delta Conflicts=-1, New Position for Row 7 -> Column 7
# Board Position: [5, 3, 0, 6, 3, 4, 2, 7]
# Iteration 234: Temperature=9.52, Current Conflicts=5, Delta Conflicts=2, New Position for Row 0 -> Column 4
# Board Position: [4, 3, 0, 6, 3, 4, 2, 7]
# Iteration 235: Temperature=9.42, Current Conflicts=5, Delta Conflicts=0, New Position for Row 4 -> Column 7
# Board Position: [4, 3, 0, 6, 7, 4, 2, 7]
# Iteration 236: Temperature=9.33, Current Conflicts=4, Delta Conflicts=-1, New Position for Row 3 -> Column 0
# Board Position: [4, 3, 0, 0, 7, 4, 2, 7]
# Iteration 237: Temperature=9.24, Current Conflicts=4, Delta Conflicts=0, New Position for Row 5 -> Column 1
# Board Position: [4, 3, 0, 0, 7, 1, 2, 7]
# Iteration 238: Temperature=9.14, Current Conflicts=5, Delta Conflicts=1, New Position for Row 1 -> Column 2
# Board Position: [4, 2, 0, 0, 7, 1, 2, 7]
# Iteration 239: Temperature=9.05, Current Conflicts=6, Delta Conflicts=1, New Position for Row 6 -> Column 7
# Board Position: [4, 2, 0, 0, 7, 1, 7, 7]
# Iteration 240: Temperature=8.96, Current Conflicts=8, Delta Conflicts=2, New Position for Row 2 -> Column 7
# Board Position: [4, 2, 7, 0, 7, 1, 7, 7]
# Iteration 241: Temperature=8.87, Current Conflicts=10, Delta Conflicts=2, New Position for Row 0 -> Column 0
# Board Position: [0, 2, 7, 0, 7, 1, 7, 7]
# Iteration 242: Temperature=8.78, Current Conflicts=11, Delta Conflicts=1, New Position for Row 1 -> Column 1
# Board Position: [0, 1, 7, 0, 7, 1, 7, 7]
# Iteration 243: Temperature=8.70, Current Conflicts=9, Delta Conflicts=-2, New Position for Row 2 -> Column 4
# Board Position: [0, 1, 4, 0, 7, 1, 7, 7]
# Iteration 244: Temperature=8.61, Current Conflicts=9, Delta Conflicts=0, New Position for Row 2 -> Column 5
# Board Position: [0, 1, 5, 0, 7, 1, 7, 7]
# Iteration 245: Temperature=8.52, Current Conflicts=10, Delta Conflicts=1, New Position for Row 6 -> Column 6
# Board Position: [0, 1, 5, 0, 7, 1, 6, 7]
# Iteration 246: Temperature=8.44, Current Conflicts=8, Delta Conflicts=-2, New Position for Row 7 -> Column 5
# Board Position: [0, 1, 5, 0, 7, 1, 6, 5]
# Iteration 247: Temperature=8.35, Current Conflicts=10, Delta Conflicts=2, New Position for Row 3 -> Column 6
# Board Position: [0, 1, 5, 6, 7, 1, 6, 5]
# Iteration 248: Temperature=8.27, Current Conflicts=10, Delta Conflicts=0, New Position for Row 0 -> Column 1
# Board Position: [1, 1, 5, 6, 7, 1, 6, 5]
# Iteration 249: Temperature=8.19, Current Conflicts=8, Delta Conflicts=-2, New Position for Row 6 -> Column 3
# Board Position: [1, 1, 5, 6, 7, 1, 3, 5]
# Iteration 250: Temperature=8.11, Current Conflicts=9, Delta Conflicts=1, New Position for Row 3 -> Column 1
# Board Position: [1, 1, 5, 1, 7, 1, 3, 5]
# Iteration 251: Temperature=8.02, Current Conflicts=8, Delta Conflicts=-1, New Position for Row 0 -> Column 5
# Board Position: [5, 1, 5, 1, 7, 1, 3, 5]
# Iteration 252: Temperature=7.94, Current Conflicts=7, Delta Conflicts=-1, New Position for Row 5 -> Column 4
# Board Position: [5, 1, 5, 1, 7, 4, 3, 5]
# Iteration 253: Temperature=7.87, Current Conflicts=8, Delta Conflicts=1, New Position for Row 5 -> Column 7
# Board Position: [5, 1, 5, 1, 7, 7, 3, 5]
# Iteration 254: Temperature=7.79, Current Conflicts=7, Delta Conflicts=-1, New Position for Row 7 -> Column 7
# Board Position: [5, 1, 5, 1, 7, 7, 3, 7]
# Iteration 255: Temperature=7.71, Current Conflicts=9, Delta Conflicts=2, New Position for Row 3 -> Column 5
# Board Position: [5, 1, 5, 5, 7, 7, 3, 7]
# Iteration 256: Temperature=7.63, Current Conflicts=6, Delta Conflicts=-3, New Position for Row 4 -> Column 0
# Board Position: [5, 1, 5, 5, 0, 7, 3, 7]
# Iteration 257: Temperature=7.56, Current Conflicts=8, Delta Conflicts=2, New Position for Row 2 -> Column 7
# Board Position: [5, 1, 7, 5, 0, 7, 3, 7]
# Iteration 258: Temperature=7.48, Current Conflicts=12, Delta Conflicts=4, New Position for Row 4 -> Column 5
# Board Position: [5, 1, 7, 5, 5, 7, 3, 7]
# Iteration 259: Temperature=7.40, Current Conflicts=10, Delta Conflicts=-2, New Position for Row 2 -> Column 3
# Board Position: [5, 1, 3, 5, 5, 7, 3, 7]
# Iteration 260: Temperature=7.33, Current Conflicts=10, Delta Conflicts=0, New Position for Row 5 -> Column 0
# Board Position: [5, 1, 3, 5, 5, 0, 3, 7]
# Iteration 261: Temperature=7.26, Current Conflicts=10, Delta Conflicts=0, New Position for Row 2 -> Column 7
# Board Position: [5, 1, 7, 5, 5, 0, 3, 7]
# Iteration 262: Temperature=7.18, Current Conflicts=11, Delta Conflicts=1, New Position for Row 1 -> Column 6
# Board Position: [5, 6, 7, 5, 5, 0, 3, 7]
# Iteration 263: Temperature=7.11, Current Conflicts=13, Delta Conflicts=2, New Position for Row 5 -> Column 7
# Board Position: [5, 6, 7, 5, 5, 7, 3, 7]
# Iteration 264: Temperature=7.04, Current Conflicts=9, Delta Conflicts=-4, New Position for Row 4 -> Column 0
# Board Position: [5, 6, 7, 5, 0, 7, 3, 7]
# Iteration 265: Temperature=6.97, Current Conflicts=8, Delta Conflicts=-1, New Position for Row 0 -> Column 0
# Board Position: [0, 6, 7, 5, 0, 7, 3, 7]
# Iteration 266: Temperature=6.90, Current Conflicts=7, Delta Conflicts=-1, New Position for Row 6 -> Column 4
# Board Position: [0, 6, 7, 5, 0, 7, 4, 7]
# Iteration 267: Temperature=6.83, Current Conflicts=7, Delta Conflicts=0, New Position for Row 4 -> Column 3
# Board Position: [0, 6, 7, 5, 3, 7, 4, 7]
# Iteration 268: Temperature=6.76, Current Conflicts=5, Delta Conflicts=-2, New Position for Row 5 -> Column 0
# Board Position: [0, 6, 7, 5, 3, 0, 4, 7]
# Iteration 269: Temperature=6.70, Current Conflicts=7, Delta Conflicts=2, New Position for Row 5 -> Column 3
# Board Position: [0, 6, 7, 5, 3, 3, 4, 7]
# Iteration 270: Temperature=6.63, Current Conflicts=9, Delta Conflicts=2, New Position for Row 3 -> Column 7
# Board Position: [0, 6, 7, 7, 3, 3, 4, 7]
# Iteration 271: Temperature=6.56, Current Conflicts=10, Delta Conflicts=1, New Position for Row 5 -> Column 4
# Board Position: [0, 6, 7, 7, 3, 4, 4, 7]
# Iteration 272: Temperature=6.50, Current Conflicts=7, Delta Conflicts=-3, New Position for Row 2 -> Column 3
# Board Position: [0, 6, 3, 7, 3, 4, 4, 7]
# Iteration 273: Temperature=6.43, Current Conflicts=7, Delta Conflicts=2, New Position for Row 0 -> Column 4
# Board Position: [0, 6, 3, 7, 3, 4, 4, 7]
# Iteration 274: Temperature=6.37, Current Conflicts=7, Delta Conflicts=2, New Position for Row 3 -> Column 3
# Board Position: [0, 6, 3, 7, 3, 4, 4, 7]
# Iteration 275: Temperature=6.30, Current Conflicts=8, Delta Conflicts=1, New Position for Row 1 -> Column 3
# Board Position: [0, 3, 3, 7, 3, 4, 4, 7]
# Iteration 276: Temperature=6.24, Current Conflicts=8, Delta Conflicts=2, New Position for Row 3 -> Column 4
# Board Position: [0, 3, 3, 7, 3, 4, 4, 7]
# Iteration 277: Temperature=6.18, Current Conflicts=6, Delta Conflicts=-2, New Position for Row 5 -> Column 1
# Board Position: [0, 3, 3, 7, 3, 1, 4, 7]
# Iteration 278: Temperature=6.12, Current Conflicts=6, Delta Conflicts=0, New Position for Row 6 -> Column 5
# Board Position: [0, 3, 3, 7, 3, 1, 5, 7]
# Iteration 279: Temperature=6.06, Current Conflicts=6, Delta Conflicts=2, New Position for Row 0 -> Column 7
# Board Position: [0, 3, 3, 7, 3, 1, 5, 7]
# Iteration 280: Temperature=6.00, Current Conflicts=8, Delta Conflicts=2, New Position for Row 6 -> Column 7
# Board Position: [0, 3, 3, 7, 3, 1, 7, 7]
# Iteration 281: Temperature=5.94, Current Conflicts=6, Delta Conflicts=-2, New Position for Row 2 -> Column 0
# Board Position: [0, 3, 0, 7, 3, 1, 7, 7]
# Iteration 282: Temperature=5.88, Current Conflicts=6, Delta Conflicts=0, New Position for Row 0 -> Column 4
# Board Position: [4, 3, 0, 7, 3, 1, 7, 7]
# Iteration 283: Temperature=5.82, Current Conflicts=9, Delta Conflicts=3, New Position for Row 2 -> Column 3
# Board Position: [4, 3, 3, 7, 3, 1, 7, 7]
# Iteration 284: Temperature=5.76, Current Conflicts=8, Delta Conflicts=-1, New Position for Row 3 -> Column 2
# Board Position: [4, 3, 3, 2, 3, 1, 7, 7]
# Iteration 285: Temperature=5.70, Current Conflicts=8, Delta Conflicts=0, New Position for Row 1 -> Column 4
# Board Position: [4, 4, 3, 2, 3, 1, 7, 7]
# Iteration 286: Temperature=5.65, Current Conflicts=8, Delta Conflicts=0, New Position for Row 7 -> Column 0
# Board Position: [4, 4, 3, 2, 3, 1, 7, 0]
# Iteration 287: Temperature=5.59, Current Conflicts=8, Delta Conflicts=0, New Position for Row 1 -> Column 3
# Board Position: [4, 3, 3, 2, 3, 1, 7, 0]
# Iteration 288: Temperature=5.53, Current Conflicts=8, Delta Conflicts=0, New Position for Row 7 -> Column 1
# Board Position: [4, 3, 3, 2, 3, 1, 7, 1]
# Iteration 289: Temperature=5.48, Current Conflicts=7, Delta Conflicts=-1, New Position for Row 2 -> Column 4
# Board Position: [4, 3, 4, 2, 3, 1, 7, 1]
# Iteration 290: Temperature=5.42, Current Conflicts=7, Delta Conflicts=2, New Position for Row 3 -> Column 5
# Board Position: [4, 3, 4, 2, 3, 1, 7, 1]
# Iteration 291: Temperature=5.37, Current Conflicts=6, Delta Conflicts=-1, New Position for Row 5 -> Column 0
# Board Position: [4, 3, 4, 2, 3, 0, 7, 1]
# Iteration 292: Temperature=5.31, Current Conflicts=6, Delta Conflicts=0, New Position for Row 0 -> Column 1
# Board Position: [1, 3, 4, 2, 3, 0, 7, 1]
# Iteration 293: Temperature=5.26, Current Conflicts=6, Delta Conflicts=0, New Position for Row 0 -> Column 7
# Board Position: [7, 3, 4, 2, 3, 0, 7, 1]
# Iteration 294: Temperature=5.21, Current Conflicts=7, Delta Conflicts=1, New Position for Row 2 -> Column 5
# Board Position: [7, 3, 5, 2, 3, 0, 7, 1]
# Iteration 295: Temperature=5.16, Current Conflicts=7, Delta Conflicts=1, New Position for Row 6 -> Column 0
# Board Position: [7, 3, 5, 2, 3, 0, 7, 1]
# Iteration 296: Temperature=5.11, Current Conflicts=10, Delta Conflicts=3, New Position for Row 5 -> Column 2
# Board Position: [7, 3, 5, 2, 3, 2, 7, 1]
# Iteration 297: Temperature=5.05, Current Conflicts=11, Delta Conflicts=1, New Position for Row 1 -> Column 0
# Board Position: [7, 0, 5, 2, 3, 2, 7, 1]
# Iteration 298: Temperature=5.00, Current Conflicts=10, Delta Conflicts=-1, New Position for Row 1 -> Column 3
# Board Position: [7, 3, 5, 2, 3, 2, 7, 1]
# Iteration 299: Temperature=4.95, Current Conflicts=8, Delta Conflicts=-2, New Position for Row 2 -> Column 6
# Board Position: [7, 3, 6, 2, 3, 2, 7, 1]
# Iteration 300: Temperature=4.90, Current Conflicts=5, Delta Conflicts=-3, New Position for Row 0 -> Column 0
# Board Position: [0, 3, 6, 2, 3, 2, 7, 1]
# Iteration 301: Temperature=4.86, Current Conflicts=5, Delta Conflicts=0, New Position for Row 3 -> Column 1
# Board Position: [0, 3, 6, 1, 3, 2, 7, 1]
# Iteration 302: Temperature=4.81, Current Conflicts=6, Delta Conflicts=1, New Position for Row 1 -> Column 6
# Board Position: [0, 6, 6, 1, 3, 2, 7, 1]
# Iteration 303: Temperature=4.76, Current Conflicts=8, Delta Conflicts=2, New Position for Row 5 -> Column 3
# Board Position: [0, 6, 6, 1, 3, 3, 7, 1]
# Iteration 304: Temperature=4.71, Current Conflicts=8, Delta Conflicts=3, New Position for Row 6 -> Column 2
# Board Position: [0, 6, 6, 1, 3, 3, 7, 1]
# Iteration 305: Temperature=4.66, Current Conflicts=6, Delta Conflicts=-2, New Position for Row 5 -> Column 2
# Board Position: [0, 6, 6, 1, 3, 2, 7, 1]
# Iteration 306: Temperature=4.62, Current Conflicts=6, Delta Conflicts=0, New Position for Row 4 -> Column 0
# Board Position: [0, 6, 6, 1, 0, 2, 7, 1]
# Iteration 307: Temperature=4.57, Current Conflicts=7, Delta Conflicts=1, New Position for Row 0 -> Column 6
# Board Position: [6, 6, 6, 1, 0, 2, 7, 1]
# Iteration 308: Temperature=4.53, Current Conflicts=6, Delta Conflicts=-1, New Position for Row 2 -> Column 7
# Board Position: [6, 6, 7, 1, 0, 2, 7, 1]
# Iteration 309: Temperature=4.48, Current Conflicts=5, Delta Conflicts=-1, New Position for Row 3 -> Column 5
# Board Position: [6, 6, 7, 5, 0, 2, 7, 1]
# Iteration 310: Temperature=4.44, Current Conflicts=4, Delta Conflicts=-1, New Position for Row 2 -> Column 1
# Board Position: [6, 6, 1, 5, 0, 2, 7, 1]
# Iteration 311: Temperature=4.39, Current Conflicts=4, Delta Conflicts=0, New Position for Row 5 -> Column 4
# Board Position: [6, 6, 1, 5, 0, 4, 7, 1]
# Iteration 312: Temperature=4.35, Current Conflicts=3, Delta Conflicts=-1, New Position for Row 7 -> Column 5
# Board Position: [6, 6, 1, 5, 0, 4, 7, 5]
# Iteration 313: Temperature=4.30, Current Conflicts=3, Delta Conflicts=4, New Position for Row 6 -> Column 5
# Board Position: [6, 6, 1, 5, 0, 4, 7, 5]
# Iteration 314: Temperature=4.26, Current Conflicts=4, Delta Conflicts=1, New Position for Row 4 -> Column 7
# Board Position: [6, 6, 1, 5, 7, 4, 7, 5]
# Iteration 315: Temperature=4.22, Current Conflicts=5, Delta Conflicts=1, New Position for Row 5 -> Column 3
# Board Position: [6, 6, 1, 5, 7, 3, 7, 5]
# Iteration 316: Temperature=4.18, Current Conflicts=9, Delta Conflicts=4, New Position for Row 2 -> Column 6
# Board Position: [6, 6, 6, 5, 7, 3, 7, 5]
# Iteration 317: Temperature=4.13, Current Conflicts=9, Delta Conflicts=0, New Position for Row 6 -> Column 3
# Board Position: [6, 6, 6, 5, 7, 3, 3, 5]
# Iteration 318: Temperature=4.09, Current Conflicts=9, Delta Conflicts=0, New Position for Row 6 -> Column 1
# Board Position: [6, 6, 6, 5, 7, 3, 1, 5]
# Iteration 319: Temperature=4.05, Current Conflicts=10, Delta Conflicts=1, New Position for Row 3 -> Column 6
# Board Position: [6, 6, 6, 6, 7, 3, 1, 5]
# ...
# Board Position: [2, 2, 7, 0, 1, 4, 0, 3]
# Iteration 512: Temperature=0.58, Current Conflicts=3, Delta Conflicts=-2, New Position for Row 3 -> Column 5
# Board Position: [2, 2, 7, 5, 1, 4, 0, 3]
# Iteration 513: Temperature=0.58, Current Conflicts=2, Delta Conflicts=-1, New Position for Row 0 -> Column 0
# Board Position: [0, 2, 7, 5, 1, 4, 0, 3]
# Iteration 514: Temperature=0.57, Current Conflicts=2, Delta Conflicts=2, New Position for Row 5 -> Column 1
# Board Position: [0, 2, 7, 5, 1, 4, 0, 3]
# Iteration 515: Temperature=0.57, Current Conflicts=2, Delta Conflicts=0, New Position for Row 0 -> Column 6
# Board Position: [6, 2, 7, 5, 1, 4, 0, 3]
# Iteration 516: Temperature=0.56, Current Conflicts=2, Delta Conflicts=1, New Position for Row 5 -> Column 7
# Board Position: [6, 2, 7, 5, 1, 4, 0, 3]
# Iteration 517: Temperature=0.55, Current Conflicts=2, Delta Conflicts=0, New Position for Row 6 -> Column 1
# Board Position: [6, 2, 7, 5, 1, 4, 1, 3]
# Iteration 518: Temperature=0.55, Current Conflicts=2, Delta Conflicts=0, New Position for Row 0 -> Column 0
# Board Position: [0, 2, 7, 5, 1, 4, 1, 3]
# Iteration 519: Temperature=0.54, Current Conflicts=2, Delta Conflicts=2, New Position for Row 4 -> Column 4
# Board Position: [0, 2, 7, 5, 1, 4, 1, 3]
# Iteration 520: Temperature=0.54, Current Conflicts=2, Delta Conflicts=3, New Position for Row 3 -> Column 4
# Board Position: [0, 2, 7, 5, 1, 4, 1, 3]
# Iteration 521: Temperature=0.53, Current Conflicts=2, Delta Conflicts=3, New Position for Row 0 -> Column 5
# Board Position: [0, 2, 7, 5, 1, 4, 1, 3]
# Iteration 522: Temperature=0.53, Current Conflicts=2, Delta Conflicts=1, New Position for Row 5 -> Column 3
# Board Position: [0, 2, 7, 5, 1, 4, 1, 3]
# Iteration 523: Temperature=0.52, Current Conflicts=2, Delta Conflicts=2, New Position for Row 5 -> Column 5
# Board Position: [0, 2, 7, 5, 1, 4, 1, 3]
# Iteration 524: Temperature=0.52, Current Conflicts=2, Delta Conflicts=3, New Position for Row 1 -> Column 1
# Board Position: [0, 2, 7, 5, 1, 4, 1, 3]
# Iteration 525: Temperature=0.51, Current Conflicts=2, Delta Conflicts=2, New Position for Row 5 -> Column 2
# Board Position: [0, 2, 7, 5, 1, 4, 1, 3]
# Iteration 526: Temperature=0.51, Current Conflicts=2, Delta Conflicts=0, New Position for Row 5 -> Column 6
# Board Position: [0, 2, 7, 5, 1, 6, 1, 3]
# Iteration 527: Temperature=0.50, Current Conflicts=2, Delta Conflicts=1, New Position for Row 0 -> Column 6
# Board Position: [0, 2, 7, 5, 1, 6, 1, 3]
# Iteration 528: Temperature=0.50, Current Conflicts=2, Delta Conflicts=0, New Position for Row 1 -> Column 5
# Board Position: [0, 5, 7, 5, 1, 6, 1, 3]
# Iteration 529: Temperature=0.49, Current Conflicts=2, Delta Conflicts=3, New Position for Row 2 -> Column 3
# Board Position: [0, 5, 7, 5, 1, 6, 1, 3]
# Iteration 530: Temperature=0.49, Current Conflicts=4, Delta Conflicts=2, New Position for Row 0 -> Column 7
# Board Position: [7, 5, 7, 5, 1, 6, 1, 3]
# Iteration 531: Temperature=0.48, Current Conflicts=3, Delta Conflicts=-1, New Position for Row 0 -> Column 3
# Board Position: [3, 5, 7, 5, 1, 6, 1, 3]
# Iteration 532: Temperature=0.48, Current Conflicts=3, Delta Conflicts=1, New Position for Row 5 -> Column 4
# Board Position: [3, 5, 7, 5, 1, 6, 1, 3]
# Iteration 533: Temperature=0.47, Current Conflicts=3, Delta Conflicts=1, New Position for Row 0 -> Column 6
# Board Position: [3, 5, 7, 5, 1, 6, 1, 3]
# Iteration 534: Temperature=0.47, Current Conflicts=3, Delta Conflicts=3, New Position for Row 4 -> Column 5
# Board Position: [3, 5, 7, 5, 1, 6, 1, 3]
# Iteration 535: Temperature=0.46, Current Conflicts=3, Delta Conflicts=1, New Position for Row 1 -> Column 1
# Board Position: [3, 5, 7, 5, 1, 6, 1, 3]
# Iteration 536: Temperature=0.46, Current Conflicts=3, Delta Conflicts=1, New Position for Row 0 -> Column 6
# Board Position: [3, 5, 7, 5, 1, 6, 1, 3]
# Iteration 537: Temperature=0.45, Current Conflicts=3, Delta Conflicts=4, New Position for Row 5 -> Column 1
# Board Position: [3, 5, 7, 5, 1, 6, 1, 3]
# Iteration 538: Temperature=0.45, Current Conflicts=3, Delta Conflicts=4, New Position for Row 5 -> Column 1
# Board Position: [3, 5, 7, 5, 1, 6, 1, 3]
# Iteration 539: Temperature=0.44, Current Conflicts=3, Delta Conflicts=1, New Position for Row 3 -> Column 0
# Board Position: [3, 5, 7, 5, 1, 6, 1, 3]
# Iteration 540: Temperature=0.44, Current Conflicts=3, Delta Conflicts=0, New Position for Row 0 -> Column 4
# Board Position: [4, 5, 7, 5, 1, 6, 1, 3]
# Iteration 541: Temperature=0.44, Current Conflicts=3, Delta Conflicts=1, New Position for Row 3 -> Column 3
# Board Position: [4, 5, 7, 5, 1, 6, 1, 3]
# Iteration 542: Temperature=0.43, Current Conflicts=3, Delta Conflicts=2, New Position for Row 5 -> Column 0
# Board Position: [4, 5, 7, 5, 1, 6, 1, 3]
# Iteration 543: Temperature=0.43, Current Conflicts=3, Delta Conflicts=0, New Position for Row 6 -> Column 6
# Board Position: [4, 5, 7, 5, 1, 6, 6, 3]
# Iteration 544: Temperature=0.42, Current Conflicts=3, Delta Conflicts=1, New Position for Row 4 -> Column 3
# Board Position: [4, 5, 7, 5, 1, 6, 6, 3]
# Iteration 545: Temperature=0.42, Current Conflicts=3, Delta Conflicts=0, New Position for Row 6 -> Column 1
# Board Position: [4, 5, 7, 5, 1, 6, 1, 3]
# Iteration 546: Temperature=0.41, Current Conflicts=3, Delta Conflicts=2, New Position for Row 2 -> Column 1
# Board Position: [4, 5, 7, 5, 1, 6, 1, 3]
# Iteration 547: Temperature=0.41, Current Conflicts=3, Delta Conflicts=3, New Position for Row 5 -> Column 5
# Board Position: [4, 5, 7, 5, 1, 6, 1, 3]
# Iteration 548: Temperature=0.41, Current Conflicts=3, Delta Conflicts=1, New Position for Row 6 -> Column 2
# Board Position: [4, 5, 7, 5, 1, 6, 1, 3]
# Iteration 549: Temperature=0.40, Current Conflicts=3, Delta Conflicts=1, New Position for Row 7 -> Column 7
# Board Position: [4, 5, 7, 5, 1, 6, 1, 3]
# Iteration 550: Temperature=0.40, Current Conflicts=3, Delta Conflicts=1, New Position for Row 4 -> Column 3
# Board Position: [4, 5, 7, 5, 1, 6, 1, 3]
# Iteration 551: Temperature=0.39, Current Conflicts=3, Delta Conflicts=3, New Position for Row 4 -> Column 5
# Board Position: [4, 5, 7, 5, 1, 6, 1, 3]
# Iteration 552: Temperature=0.39, Current Conflicts=4, Delta Conflicts=1, New Position for Row 1 -> Column 3
# Board Position: [4, 3, 7, 5, 1, 6, 1, 3]
# Iteration 553: Temperature=0.39, Current Conflicts=3, Delta Conflicts=-1, New Position for Row 4 -> Column 2
# Board Position: [4, 3, 7, 5, 2, 6, 1, 3]
# Iteration 554: Temperature=0.38, Current Conflicts=3, Delta Conflicts=2, New Position for Row 4 -> Column 7
# Board Position: [4, 3, 7, 5, 2, 6, 1, 3]
# Iteration 555: Temperature=0.38, Current Conflicts=3, Delta Conflicts=3, New Position for Row 6 -> Column 3
# Board Position: [4, 3, 7, 5, 2, 6, 1, 3]
# Iteration 556: Temperature=0.37, Current Conflicts=1, Delta Conflicts=-2, New Position for Row 1 -> Column 1
# Board Position: [4, 1, 7, 5, 2, 6, 1, 3]
# Iteration 557: Temperature=0.37, Current Conflicts=1, Delta Conflicts=1, New Position for Row 7 -> Column 0
# Board Position: [4, 1, 7, 5, 2, 6, 1, 3]
# Iteration 558: Temperature=0.37, Current Conflicts=1, Delta Conflicts=2, New Position for Row 1 -> Column 6
# Board Position: [4, 1, 7, 5, 2, 6, 1, 3]
# Iteration 559: Temperature=0.36, Current Conflicts=1, Delta Conflicts=2, New Position for Row 1 -> Column 5
# Board Position: [4, 1, 7, 5, 2, 6, 1, 3]
# Iteration 560: Temperature=0.36, Current Conflicts=1, Delta Conflicts=2, New Position for Row 4 -> Column 3
# Board Position: [4, 1, 7, 5, 2, 6, 1, 3]
# Iteration 561: Temperature=0.36, Current Conflicts=1, Delta Conflicts=3, New Position for Row 2 -> Column 2
# Board Position: [4, 1, 7, 5, 2, 6, 1, 3]
# Iteration 562: Temperature=0.35, Current Conflicts=1, Delta Conflicts=0, New Position for Row 6 -> Column 0
# Board Position: [4, 1, 7, 5, 2, 6, 0, 3]
# Iteration 563: Temperature=0.35, Current Conflicts=1, Delta Conflicts=4, New Position for Row 5 -> Column 1
# Board Position: [4, 1, 7, 5, 2, 6, 0, 3]
# Iteration 564: Temperature=0.35, Current Conflicts=1, Delta Conflicts=3, New Position for Row 0 -> Column 6
# Board Position: [4, 1, 7, 5, 2, 6, 0, 3]
# Iteration 565: Temperature=0.34, Current Conflicts=1, Delta Conflicts=2, New Position for Row 3 -> Column 6
# Board Position: [4, 1, 7, 5, 2, 6, 0, 3]
# Iteration 566: Temperature=0.34, Current Conflicts=1, Delta Conflicts=2, New Position for Row 7 -> Column 2
# Board Position: [4, 1, 7, 5, 2, 6, 0, 3]
# Iteration 567: Temperature=0.34, Current Conflicts=1, Delta Conflicts=2, New Position for Row 0 -> Column 0
# Board Position: [4, 1, 7, 5, 2, 6, 0, 3]
# Iteration 568: Temperature=0.33, Current Conflicts=1, Delta Conflicts=1, New Position for Row 0 -> Column 3
# Board Position: [4, 1, 7, 5, 2, 6, 0, 3]
# Iteration 569: Temperature=0.33, Current Conflicts=1, Delta Conflicts=2, New Position for Row 7 -> Column 2
# Board Position: [4, 1, 7, 5, 2, 6, 0, 3]
# Iteration 570: Temperature=0.33, Current Conflicts=1, Delta Conflicts=1, New Position for Row 4 -> Column 7
# Board Position: [4, 1, 7, 5, 2, 6, 0, 3]
# Iteration 571: Temperature=0.32, Current Conflicts=1, Delta Conflicts=3, New Position for Row 3 -> Column 7
# Board Position: [4, 1, 7, 5, 2, 6, 0, 3]
# Iteration 572: Temperature=0.32, Current Conflicts=1, Delta Conflicts=2, New Position for Row 0 -> Column 5
# Board Position: [4, 1, 7, 5, 2, 6, 0, 3]
# Iteration 573: Temperature=0.32, Current Conflicts=1, Delta Conflicts=2, New Position for Row 6 -> Column 4
# Board Position: [4, 1, 7, 5, 2, 6, 0, 3]
# Iteration 574: Temperature=0.31, Current Conflicts=1, Delta Conflicts=2, New Position for Row 4 -> Column 4
# Board Position: [4, 1, 7, 5, 2, 6, 0, 3]
# Iteration 575: Temperature=0.31, Current Conflicts=1, Delta Conflicts=3, New Position for Row 7 -> Column 1
# Board Position: [4, 1, 7, 5, 2, 6, 0, 3]
# Iteration 576: Temperature=0.31, Current Conflicts=1, Delta Conflicts=1, New Position for Row 2 -> Column 1
# Board Position: [4, 1, 7, 5, 2, 6, 0, 3]
# Iteration 577: Temperature=0.30, Current Conflicts=2, Delta Conflicts=1, New Position for Row 1 -> Column 4
# Board Position: [4, 4, 7, 5, 2, 6, 0, 3]
# Iteration 578: Temperature=0.30, Current Conflicts=2, Delta Conflicts=0, New Position for Row 0 -> Column 0
# Board Position: [0, 4, 7, 5, 2, 6, 0, 3]
# Iteration 579: Temperature=0.30, Current Conflicts=2, Delta Conflicts=2, New Position for Row 7 -> Column 0
# Board Position: [0, 4, 7, 5, 2, 6, 0, 3]
# Iteration 580: Temperature=0.29, Current Conflicts=2, Delta Conflicts=3, New Position for Row 5 -> Column 1
# Board Position: [0, 4, 7, 5, 2, 6, 0, 3]
# Iteration 581: Temperature=0.29, Current Conflicts=2, Delta Conflicts=2, New Position for Row 3 -> Column 4
# Board Position: [0, 4, 7, 5, 2, 6, 0, 3]
# Iteration 582: Temperature=0.29, Current Conflicts=2, Delta Conflicts=2, New Position for Row 1 -> Column 3
# Board Position: [0, 4, 7, 5, 2, 6, 0, 3]
# Iteration 583: Temperature=0.29, Current Conflicts=2, Delta Conflicts=3, New Position for Row 5 -> Column 3
# Board Position: [0, 4, 7, 5, 2, 6, 0, 3]
# Iteration 584: Temperature=0.28, Current Conflicts=2, Delta Conflicts=0, New Position for Row 6 -> Column 5
# Board Position: [0, 4, 7, 5, 2, 6, 5, 3]
# Iteration 585: Temperature=0.28, Current Conflicts=2, Delta Conflicts=0, New Position for Row 6 -> Column 6
# Board Position: [0, 4, 7, 5, 2, 6, 6, 3]
# Iteration 586: Temperature=0.28, Current Conflicts=2, Delta Conflicts=2, New Position for Row 3 -> Column 2
# Board Position: [0, 4, 7, 5, 2, 6, 6, 3]
# Iteration 587: Temperature=0.27, Current Conflicts=2, Delta Conflicts=4, New Position for Row 4 -> Column 6
# Board Position: [0, 4, 7, 5, 2, 6, 6, 3]
# Iteration 588: Temperature=0.27, Current Conflicts=2, Delta Conflicts=1, New Position for Row 1 -> Column 0
# Board Position: [0, 4, 7, 5, 2, 6, 6, 3]
# Iteration 589: Temperature=0.27, Current Conflicts=2, Delta Conflicts=4, New Position for Row 3 -> Column 3
# Board Position: [0, 4, 7, 5, 2, 6, 6, 3]
# Iteration 590: Temperature=0.27, Current Conflicts=2, Delta Conflicts=1, New Position for Row 7 -> Column 1
# Board Position: [0, 4, 7, 5, 2, 6, 6, 3]
# Iteration 591: Temperature=0.26, Current Conflicts=2, Delta Conflicts=2, New Position for Row 1 -> Column 7
# Board Position: [0, 4, 7, 5, 2, 6, 6, 3]
# Iteration 592: Temperature=0.26, Current Conflicts=2, Delta Conflicts=4, New Position for Row 4 -> Column 6
# Board Position: [0, 4, 7, 5, 2, 6, 6, 3]
# Iteration 593: Temperature=0.26, Current Conflicts=2, Delta Conflicts=0, New Position for Row 2 -> Column 1
# Board Position: [0, 4, 1, 5, 2, 6, 6, 3]
# Iteration 594: Temperature=0.26, Current Conflicts=4, Delta Conflicts=2, New Position for Row 7 -> Column 4
# Board Position: [0, 4, 1, 5, 2, 6, 6, 4]
# Iteration 595: Temperature=0.25, Current Conflicts=4, Delta Conflicts=1, New Position for Row 6 -> Column 4
# Board Position: [0, 4, 1, 5, 2, 6, 6, 4]
# Iteration 596: Temperature=0.25, Current Conflicts=4, Delta Conflicts=0, New Position for Row 5 -> Column 0
# Board Position: [0, 4, 1, 5, 2, 0, 6, 4]
# Iteration 597: Temperature=0.25, Current Conflicts=4, Delta Conflicts=0, New Position for Row 5 -> Column 3
# Board Position: [0, 4, 1, 5, 2, 3, 6, 4]
# Iteration 598: Temperature=0.25, Current Conflicts=4, Delta Conflicts=3, New Position for Row 3 -> Column 3
# Board Position: [0, 4, 1, 5, 2, 3, 6, 4]
# Iteration 599: Temperature=0.24, Current Conflicts=4, Delta Conflicts=0, New Position for Row 4 -> Column 0
# Board Position: [0, 4, 1, 5, 0, 3, 6, 4]
# Iteration 600: Temperature=0.24, Current Conflicts=4, Delta Conflicts=1, New Position for Row 3 -> Column 6
# Board Position: [0, 4, 1, 5, 0, 3, 6, 4]
# Iteration 601: Temperature=0.24, Current Conflicts=4, Delta Conflicts=2, New Position for Row 4 -> Column 1
# Board Position: [0, 4, 1, 5, 0, 3, 6, 4]
# Iteration 602: Temperature=0.24, Current Conflicts=4, Delta Conflicts=1, New Position for Row 7 -> Column 3
# Board Position: [0, 4, 1, 5, 0, 3, 6, 4]
# Iteration 603: Temperature=0.23, Current Conflicts=4, Delta Conflicts=0, New Position for Row 4 -> Column 5
# Board Position: [0, 4, 1, 5, 5, 3, 6, 4]
# Iteration 604: Temperature=0.23, Current Conflicts=4, Delta Conflicts=2, New Position for Row 1 -> Column 1
# Board Position: [0, 4, 1, 5, 5, 3, 6, 4]
# Iteration 605: Temperature=0.23, Current Conflicts=4, Delta Conflicts=1, New Position for Row 5 -> Column 0
# Board Position: [0, 4, 1, 5, 5, 3, 6, 4]
# Iteration 606: Temperature=0.23, Current Conflicts=4, Delta Conflicts=1, New Position for Row 7 -> Column 6
# Board Position: [0, 4, 1, 5, 5, 3, 6, 4]
# Iteration 607: Temperature=0.22, Current Conflicts=4, Delta Conflicts=2, New Position for Row 0 -> Column 5
# Board Position: [0, 4, 1, 5, 5, 3, 6, 4]
# Iteration 608: Temperature=0.22, Current Conflicts=4, Delta Conflicts=3, New Position for Row 2 -> Column 6
# Board Position: [0, 4, 1, 5, 5, 3, 6, 4]
# Iteration 609: Temperature=0.22, Current Conflicts=4, Delta Conflicts=1, New Position for Row 4 -> Column 3
# Board Position: [0, 4, 1, 5, 5, 3, 6, 4]
# Iteration 610: Temperature=0.22, Current Conflicts=4, Delta Conflicts=2, New Position for Row 4 -> Column 1
# Board Position: [0, 4, 1, 5, 5, 3, 6, 4]
# Iteration 611: Temperature=0.22, Current Conflicts=4, Delta Conflicts=3, New Position for Row 5 -> Column 4
# Board Position: [0, 4, 1, 5, 5, 3, 6, 4]
# Iteration 612: Temperature=0.21, Current Conflicts=4, Delta Conflicts=3, New Position for Row 6 -> Column 5
# Board Position: [0, 4, 1, 5, 5, 3, 6, 4]
# Iteration 613: Temperature=0.21, Current Conflicts=4, Delta Conflicts=0, New Position for Row 7 -> Column 0
# Board Position: [0, 4, 1, 5, 5, 3, 6, 0]
# Iteration 614: Temperature=0.21, Current Conflicts=4, Delta Conflicts=2, New Position for Row 6 -> Column 5
# Board Position: [0, 4, 1, 5, 5, 3, 6, 0]
# Iteration 615: Temperature=0.21, Current Conflicts=3, Delta Conflicts=-1, New Position for Row 0 -> Column 2
# Board Position: [2, 4, 1, 5, 5, 3, 6, 0]
# Iteration 616: Temperature=0.20, Current Conflicts=3, Delta Conflicts=4, New Position for Row 2 -> Column 5
# Board Position: [2, 4, 1, 5, 5, 3, 6, 0]
# Iteration 617: Temperature=0.20, Current Conflicts=0, Delta Conflicts=-3, New Position for Row 3 -> Column 7
# Board Position: [2, 4, 1, 7, 5, 3, 6, 0]
# Iteration 618: Solution found!
# Board Position: [2, 4, 1, 7, 5, 3, 6, 0]
# Final Solution: [2, 4, 1, 7, 5, 3, 6, 0]
